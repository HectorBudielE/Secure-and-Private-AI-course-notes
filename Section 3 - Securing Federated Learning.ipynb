# %% [markdown]
# # Section: Securing Federated Learning
#
# - Lesson 1: Trusted Aggregator
# - Lesson 2: Intro to Additive Secret Sharing
# - Lesson 3: Intro to Fixed Precision Encoding
# - Lesson 4: Secret Sharing + Fixed Precision in PySyft
# - Final Project: Federated Learning wtih Encrypted Gradient Aggregation

# %% [markdown]
# # Lesson: Federated Learning with a Trusted Aggregator
#
# In the last section, we learned how to train a model on a distributed dataset using Federated Learning. In particular, the last project aggregated gradients directly from one data owner to another.
#
# However, while in some cases it could be ideal to do this, what would be even better is to be able to choose a neutral third party to perform the aggregation.
#
# As it turns out, we can use the same tools we used previously to accomplish this.

# %% [markdown]
# # Project: Federated Learning with a Trusted Aggregator

# %%
# !pip install tf-encrypted

! URL="https://github.com/openmined/PySyft.git" && FOLDER="PySyft" && if [ ! -d $FOLDER ]; then git clone -b dev --single-branch $URL; else (cd $FOLDER && git pull $URL && cd ..); fi;

# !cd PySyft; python setup.py install  > /dev/null

import os
import sys
module_path = os.path.abspath(os.path.join('./PySyft'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# !pip install --upgrade --force-reinstall lz4
# !pip install --upgrade --force-reinstall websocket
# !pip install --upgrade --force-reinstall websockets
# !pip install --upgrade --force-reinstall zstd
# Out:
# Collecting tf-encrypted
#   Downloading https://files.pythonhosted.org/packages/1f/82/cf15aeac92525da2f794956712e7ebf418819390dec783430ee242b52d0b/tf_encrypted-0.5.8-py3-none-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 5.0MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted) (1.16.4)
# Requirement already satisfied: tensorflow<2,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted) (1.14.0)
# Collecting pyyaml>=5.1 (from tf-encrypted)
#   Downloading https://files.pythonhosted.org/packages/e3/e8/b3212641ee2718d556df0f23f78de8303f068fe29cdaa7a91018849582fe/PyYAML-5.1.2.tar.gz (265kB)
#      |████████████████████████████████| 266kB 40.2MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (0.33.6)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.12.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (0.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (3.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.14.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (0.1.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (0.2.2)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted) (1.11.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow<2,>=1.12.0->tf-encrypted) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow<2,>=1.12.0->tf-encrypted) (41.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<2,>=1.12.0->tf-encrypted) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<2,>=1.12.0->tf-encrypted) (0.15.5)
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1.2-cp36-cp36m-linux_x86_64.whl size=44104 sha256=51cce6dfed046959a1ef66aed9b17f3ff70ddb9bf34a6c955430c4f3dfefa32e
#   Stored in directory: /root/.cache/pip/wheels/d9/45/dd/65f0b38450c47cf7e5312883deb97d065e030c5cca0a365030
# Successfully built pyyaml
# Installing collected packages: pyyaml, tf-encrypted
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1.2 tf-encrypted-0.5.8
# Cloning into 'PySyft'...
# remote: Enumerating objects: 30814, done.
# remote: Total 30814 (delta 0), reused 0 (delta 0), pack-reused 30814
# Receiving objects: 100% (30814/30814), 33.13 MiB | 24.30 MiB/s, done.
# Resolving deltas: 100% (20714/20714), done.
# zip_safe flag not set; analyzing archive contents...
# zip_safe flag not set; analyzing archive contents...
# __pycache__.zstd.cpython-36: module references __file__
# Collecting lz4
#   Downloading https://files.pythonhosted.org/packages/0a/c6/96bbb3525a63ebc53ea700cc7d37ab9045542d33b4d262d0f0408ad9bbf2/lz4-2.1.10-cp36-cp36m-manylinux1_x86_64.whl (385kB)
#      |████████████████████████████████| 389kB 5.5MB/s
# ERROR: syft 0.1.25a1 has requirement msgpack>=0.6.1, but you'll have msgpack 0.5.6 which is incompatible.
# Installing collected packages: lz4
#   Found existing installation: lz4 2.1.10
#     Uninstalling lz4-2.1.10:
#       Successfully uninstalled lz4-2.1.10
# Successfully installed lz4-2.1.10
# Collecting websocket
#   Downloading https://files.pythonhosted.org/packages/f2/6d/a60d620ea575c885510c574909d2e3ed62129b121fa2df00ca1c81024c87/websocket-0.2.1.tar.gz (195kB)
#      |████████████████████████████████| 204kB 5.0MB/s
# Collecting gevent (from websocket)
#   Downloading https://files.pythonhosted.org/packages/f2/ca/5b5962361ed832847b6b2f9a2d0452c8c2f29a93baef850bb8ad067c7bf9/gevent-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 34.7MB/s
# Collecting greenlet (from websocket)
#   Downloading https://files.pythonhosted.org/packages/bf/45/142141aa47e01a5779f0fa5a53b81f8379ce8f2b1cd13df7d2f1d751ae42/greenlet-0.4.15-cp36-cp36m-manylinux1_x86_64.whl (41kB)
#      |████████████████████████████████| 51kB 23.7MB/s
# Building wheels for collected packages: websocket
#   Building wheel for websocket (setup.py) ... done
#   Created wheel for websocket: filename=websocket-0.2.1-cp36-none-any.whl size=192135 sha256=22d38e15fe725acbc5ef6c39abc113e73e85eeeb7af2b3a85ad390b8db6d4ee5
#   Stored in directory: /root/.cache/pip/wheels/35/f7/5c/9e8243838269ea93f05295708519a6e183fa6b515d9ce3b636
# Successfully built websocket
# Installing collected packages: greenlet, gevent, websocket
#   Found existing installation: greenlet 0.4.15
#     Uninstalling greenlet-0.4.15:
#       Successfully uninstalled greenlet-0.4.15
#   Found existing installation: gevent 1.4.0
#     Uninstalling gevent-1.4.0:
#       Successfully uninstalled gevent-1.4.0
# Successfully installed gevent-1.4.0 greenlet-0.4.15 websocket-0.2.1
# Collecting websockets
#   Downloading https://files.pythonhosted.org/packages/f0/4b/ad228451b1c071c5c52616b7d4298ebcfcac5ae8515ede959db19e4cd56d/websockets-8.0.2-cp36-cp36m-manylinux1_x86_64.whl (72kB)
#      |████████████████████████████████| 81kB 5.2MB/s
# ERROR: syft 0.1.25a1 has requirement msgpack>=0.6.1, but you'll have msgpack 0.5.6 which is incompatible.
# Installing collected packages: websockets
#   Found existing installation: websockets 8.0.2
#     Uninstalling websockets-8.0.2:
#       Successfully uninstalled websockets-8.0.2
# Successfully installed websockets-8.0.2
# Collecting zstd
#   Downloading https://files.pythonhosted.org/packages/ce/73/585134600c7fe918566adddf94af42b35cb0dad4b96ee0180190fbcbb954/zstd-1.4.3.2.tar.gz (456kB)
#      |████████████████████████████████| 460kB 5.0MB/s
# Building wheels for collected packages: zstd
#   Building wheel for zstd (setup.py) ... done
#   Created wheel for zstd: filename=zstd-1.4.3.2-cp36-cp36m-linux_x86_64.whl size=1076261 sha256=9c84bfb6b31ecd878734a763291b2f03ce77981ab72a83f593235be9b0e8ebe3
#   Stored in directory: /root/.cache/pip/wheels/f2/df/a8/405bafcabba88a18c8763694e79177e2a1bbc65ac0f6b3d728
# Successfully built zstd
# ERROR: syft 0.1.25a1 has requirement msgpack>=0.6.1, but you'll have msgpack 0.5.6 which is incompatible.
# Installing collected packages: zstd
#   Found existing installation: zstd 1.4.3.2
#     Uninstalling zstd-1.4.3.2:
#       Successfully uninstalled zstd-1.4.3.2
# Successfully installed zstd-1.4.3.2

# %%
import syft as sy
import torch as th
hook = sy.TorchHook(th)
from torch import nn, optim
# Out:
# W0830 15:54:26.805673 140276412204928 hook.py:98] Torch was already hooked... skipping hooking process

# %%
# create a couple workers

bob = sy.VirtualWorker(hook, id="bob")
alice = sy.VirtualWorker(hook, id="alice")
secure_worker = sy.VirtualWorker(hook, id="secure_worker")

# %%
bob.add_workers([alice, secure_worker])
alice.add_workers([bob, secure_worker])
secure_worker.add_workers([alice, bob])
# Out:
# W0830 15:54:29.647394 140276412204928 base.py:664] Worker alice already exists. Replacing old worker which could cause                     unexpected behavior
# W0830 15:54:29.649434 140276412204928 base.py:664] Worker secure_worker already exists. Replacing old worker which could cause                     unexpected behavior
# W0830 15:54:29.651227 140276412204928 base.py:664] Worker bob already exists. Replacing old worker which could cause                     unexpected behavior
# W0830 15:54:29.652687 140276412204928 base.py:664] Worker secure_worker already exists. Replacing old worker which could cause                     unexpected behavior
# W0830 15:54:29.654448 140276412204928 base.py:664] Worker alice already exists. Replacing old worker which could cause                     unexpected behavior
# W0830 15:54:29.656310 140276412204928 base.py:664] Worker bob already exists. Replacing old worker which could cause                     unexpected behavior
# <VirtualWorker id:secure_worker #objects:10>

# %%
# A Toy Dataset
data = th.tensor([[0,0],[0,1],[1,0],[1,1.]], requires_grad=True)
target = th.tensor([[0],[0],[1],[1.]], requires_grad=True)

# %%
# Get pointer to training data on each worker by
# sending some training data to bob and alice
bobs_data = data[0:2].send(bob)
bobs_target = target[0:2].send(bob)

# %%
alices_data = data[2:].send(alice)
alices_target = target[2:].send(alice)

# %%
# Initialize a Toy model
model = nn.Linear(2,1)

# %%
for round_iter in range(10):
  
    bobs_model = model.copy().send(bob)
    alices_model = model.copy().send(alice)

    bobs_opt = optim.SGD(params=bobs_model.parameters(), lr=0.1)
    alices_opt = optim.SGD(params=alices_model.parameters(), lr=0.1)

    for i in range(10):

        bobs_opt.zero_grad()
        bobs_pred = bobs_model(bobs_data)
        bobs_loss = ((bobs_pred - bobs_target)**2).sum()
        bobs_loss.backward()

        bobs_opt.step()
        bobs_loss = bobs_loss.get().data
        bobs_loss
    
        alices_opt.zero_grad()
        alices_pred = alices_model(alices_data)
        alices_loss = ((alices_pred - alices_target)**2).sum()
        alices_loss.backward()

        alices_opt.step()
        alices_loss = alices_loss.get().data
        alices_loss
    
    alices_model.move(secure_worker)
    bobs_model.move(secure_worker)

    model.weight.data.set_(((alices_model.weight.data + bobs_model.weight.data) / 2).get())
    model.bias.data.set_(((alices_model.bias.data + bobs_model.bias.data) / 2).get())
    
    secure_worker.clear_objects()
    
    print("Bob:" + str(bobs_loss) + " Alice:" + str(alice_loss))

# %% [markdown]
# # Lesson: Intro to Additive Secret Sharing
#
# While being able to have a trusted third party to perform the aggregation is certainly nice, in an ideal setting we wouldn't have to trust anyone at all. This is where Cryptography can provide an interesting alterantive.
#
# Specifically, we're going to be looking at a simple protocol for Secure Multi-Party Computation called Additive Secret Sharing. This protocol will allow multiple parties (of size 3 or more) to aggregate their gradients without the use of a trusted 3rd party to perform the aggregation. In other words, we can add 3 numbers together from 3 different people without anyone ever learning the inputs of any other actors.
#
# Let's start by considering the number 5, which we'll put into a varible x

# %%
x = 5

# %% [markdown]
# Let's say we wanted to SHARE the ownership of this number between two people, Alice and Bob. We could split this number into two shares, 2, and 3, and give one to Alice and one to Bob

# %%
bob_x_share = 2
alice_x_share = 3

decrypted_x = bob_x_share + alice_x_share
decrypted_x
# Out:
# 5

# %% [markdown]
# Note that neither Bob nor Alice know the value of x. They only know the value of their own SHARE of x. Thus, the true value of X is hidden (i.e., encrypted).
#
# The truly amazing thing, however, is that Alice and Bob can still compute using this value! They can perform arithmetic over the hidden value! Let's say Bob and Alice wanted to multiply this value by 2! If each of them multiplied their respective share by 2, then the hidden number between them is also multiplied! Check it out!

# %%
bob_x_share = 2 * 2
alice_x_share = 3 * 2

decrypted_x = bob_x_share + alice_x_share
decrypted_x
# Out:
# 10

# %% [markdown]
# This even works for addition between two shared values!!

# %%
# encrypted "5"
bob_x_share = 2
alice_x_share = 3

# encrypted "7"
bob_y_share = 5
alice_y_share = 2

# encrypted 5 + 7
bob_z_share = bob_x_share + bob_y_share
alice_z_share = alice_x_share + alice_y_share

decrypted_z = bob_z_share + alice_z_share
decrypted_z
# Out:
# 12

# %% [markdown]
# As you can see, we just added two numbers together while they were still encrypted!!!
#
# One small tweak - notice that since all our numbers are positive, it's possible for each share to reveal a little bit of information about the hidden value, namely, it's always greater than the share. Thus, if Bob has a share "3" then he knows that the encrypted value is at least 3.
#
# This would be quite bad, but can be solved through a simple fix. Decryption happens by summing all the shares together MODULUS some constant. I.e.

# %%
x = 5

Q = 23740629843760239486723

bob_x_share = 23552870267 # <- a random number
alice_x_share = Q - bob_x_share + x
alice_x_share
# Out:
# 23740629843736686616461

# %%
(bob_x_share + alice_x_share) % Q
# Out:
# 5

# %% [markdown]
# So now, as you can see, both shares are wildly larger than the number being shared, meaning that individual shares no longer leak this inforation. However, all the properties we discussed earlier still hold! (addition, encryption, decryption, etc.)

# %% [markdown]
# # Project: Build Methods for Encrypt, Decrypt, and Add
#
# In this project, you must take the lessons we learned in the last section and write general methods for encrypt, decrypt, and add. Store shares for a variable in a tuple like so.

# %%
x_share = (2,5,7)

# %% [markdown]
# Even though normally those shares would be distributed amongst several workers, you can store them in ordered tuples like this for now :)

# %%
import random

# %%
Q = 23740629843760239486723

# %%
x = 5

# %%
def encrypt(x, n_shares=3):
    
    shares = list()

    for i in range(n_shares - 1):
        shares.append(random.randint(0,Q))
        
    final_share = Q - (sum(shares) % Q) + x
    
    shares.append(final_share)
    
    return tuple(shares)

# %%
encrypt(5)
# Out:
# (2830250855086663900433, 6319250441568707784694, 14591128547104867801601)

# %%
def decrypt(shares):
    return sum(shares) % Q

# %%
decrypt(encrypt(5))
# Out:
# 5

# %%
def add(a, b):
    
    c = list()
    
    assert(len(a) == len(b))
    
    for i in range(len(a)):
        c.append((a[i] + b[i]) % Q)
        
    return tuple(c)

# %%
decrypt(add(encrypt(5), encrypt(10)))
# Out:
# 15

# %% [markdown]
# # Lesson: Intro to Fixed Precision Encoding
#
# As you may remember, our goal is to aggregate gradients using this new Secret Sharing technique. However, the protocol we've just explored in the last section uses positive integers. However, our neural network weights are NOT integers. Instead, our weights are decimals (floating point numbers).
#
# Not a huge deal! We just need to use a fixed precision encoding, which lets us do computation over decimal numbers using integers!

# %%
BASE=10
PRECISION=4

# %%
def encode(x):
    return int((x * (BASE ** PRECISION)) % Q)

def decode(x):
    return (x if x <= Q/2 else x - Q) / BASE**PRECISION

# %%
encode(3.5)
# Out:
# 35000

# %%
decode(35000)
# Out:
# 3.5

# %%
x = encrypt(encode(5.5))
y = encrypt(encode(2.3))
z = add(x,y)
decode(decrypt(z))
# Out:
# 7.8

# %% [markdown]
# # Lesson: Secret Sharing + Fixed Precision in PySyft
#
# While writing things from scratch is certainly educational, PySyft makes a great deal of this much easier for us through its abstractions.

# %%
bob = bob.clear_objects()
alice = alice.clear_objects()
secure_worker = secure_worker.clear_objects()

# %%
x = th.tensor([1,2,3,4,5])

# %% [markdown]
# ### Secret Sharing Using PySyft
#
# We can share using the simple .share() method!

# %%
x = x.share(bob, alice, secure_worker)

# %%
bob._objects
# Out:
# {68257251433: tensor([4148769462810066502, 2987875267660969827,  927629323423579988,
#          2147673484247130819, 1010741658053893740])}

# %% [markdown]
# and as you can see, Bob now has one of the shares of x! Furthermore, we can still call addition in this state, and PySyft will automatically perform the remote execution for us!

# %%
y = x + x

# %%
y
# Out:
# (Wrapper)>[AdditiveSharingTensor]
# 	-> [PointerTensor | me:23515239594 -> bob:15129408939]
# 	-> [PointerTensor | me:41631892695 -> alice:94273981352]
# 	-> [PointerTensor | me:81486441829 -> secure_worker:17062261826]
# 	*crypto provider: me*

# %%
y.get()
# Out:
# tensor([ 2,  4,  6,  8, 10])

# %% [markdown]
# ### Fixed Precision using PySyft
#
# We can also convert a tensor to fixed precision using .fix_precision()

# %%
x = th.tensor([0.1,0.2,0.3])

# %%
x
# Out:
# tensor([0.1000, 0.2000, 0.3000])

# %%
x = x.fix_prec()

# %%
x.child.child
# Out:
# tensor([100, 200, 300])

# %%
y = x + x

# %%
y = y.float_prec()
y
# Out:
# tensor([0.2000, 0.4000, 0.6000])

# %% [markdown]
# ### Shared Fixed Precision
#
# And of course, we can combine the two!

# %%
x = th.tensor([0.1, 0.2, 0.3])

# %%
x = x.fix_prec().share(bob, alice, secure_worker)

# %%
y = x + x

# %%
y.get().float_prec()
# Out:
# tensor([0.2000, 0.4000, 0.6000])

# %% [markdown]
# Make sure to make the point that people can see the model averages in the clear.
